# %%
import numpy as np
from matplotlib import pyplot as plt

list1=[34.387699, 17.427866, 12.186011, 9.200484, 7.527608, 6.324201, 5.42355, 4.842041, 4.610986, 4.159746, 3.792605, 3.627111, 3.679199, 3.293249, 3.159986, 2.891229, 3.382495, 3.35593, 3.382317, 3.34701, 3.266596, 3.128556, 3.06895, 3.000632]
plt.xlabel("threads")
plt.ylabel("time")
x=np.arange(1,25)
my_x_ticks = np.arange(1, 25, 1)
plt.xticks(my_x_ticks)
plt.plot(x,list1)
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

list_1000000000=[34.404222, 17.470119, 12.155195, 9.196006, 7.542183, 6.27237, 5.609998, 4.800844, 4.605381, 4.202912, 3.797115, 3.523217, 3.545004, 3.388263, 3.075209, 2.991392]
list_125000000=[4.372888, 2.236886, 1.568122, 1.194614, 0.976533, 0.816425, 0.712426, 0.628002, 0.603353, 0.541191, 0.498816, 0.462655, 0.461553, 0.428295, 0.406925, 0.38515]
list_2000000000=[68.876524, 35.675456, 24.204718, 18.338744, 14.972976, 12.510886, 10.761261, 9.603055, 9.151541, 8.253612, 7.529934, 7.005913, 7.029233, 6.533254, 6.175181, 5.839958]
list_250000000=[8.67154, 4.424193, 3.086579, 2.346865, 1.91537, 1.614441, 1.38832, 1.263471, 1.191771, 1.071175, 0.977287, 0.916949, 0.912455, 0.861164, 0.791068, 0.743534]
list_31250000=[1.123548, 0.577291, 0.408812, 0.314011, 0.253344, 0.222719, 0.19256, 0.170476, 0.160013, 0.145692, 0.136011, 0.127775, 0.122359, 0.132143, 0.106763, 0.100067]
list_500000000=[17.285552, 8.773054, 6.115213, 4.631337, 3.788197, 3.167589, 2.726858, 2.434434, 2.332563, 2.183517, 1.958292, 1.826522, 1.799375, 1.670006, 1.556398, 1.467393]
list_62500000=[2.291755, 1.147041, 0.797406, 0.609954, 0.498382, 0.415717, 0.375328, 0.322227, 0.307896, 0.271312, 0.256316, 0.240589, 0.23825, 0.215903, 0.202387, 0.208121]
plt.xlabel("threads")
plt.ylabel("time")
x=np.arange(1,17)
my_x_ticks = np.arange(1, 17, 1)
plt.xticks(my_x_ticks)
plt.plot(x,list_1000000000,label='1000000000')
plt.plot(x,list_125000000,label='125000000')
plt.plot(x,list_2000000000,label='2000000000')
plt.plot(x,list_250000000,label='250000000')
plt.plot(x,list_31250000,label='31250000')
plt.plot(x,list_500000000,label='500000000')
plt.plot(x,list_62500000,label='62500000')
plt.legend()
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

list_24=[88.764841, 42.587759, 28.73734, 21.473543, 18.204345, 15.214635, 14.116636, 11.840669, 11.492674, 10.649313, 9.676898, 9.556455, 8.227293, 7.842116, 7.341416, 6.692567, 7.279233, 7.11553, 7.368631, 7.145351, 7.469218, 7.06408, 7.350729, 7.055806]
list_16=[68.876524, 35.675456, 24.204718, 18.338744, 14.972976, 12.510886, 10.761261, 9.603055, 9.151541, 8.253612, 7.529934, 7.005913, 7.029233, 6.533254, 6.175181, 5.839958,None,None,None,None,None,None,None,None]

plt.xlabel("threads")
plt.ylabel("time")
x=np.arange(1,25)
my_x_ticks = np.arange(1, 25, 1)
plt.xticks(my_x_ticks)
plt.plot(x,list_24,label='thread 24')
plt.plot(x,list_16,label='thread 16')
plt.legend()
plt.show()
